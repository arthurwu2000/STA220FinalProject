# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import requests
import requests_cache
import json
import lxml.html as lx
from lxml import etree
from bs4 import BeautifulSoup
import time
from tqdm import tqdm

import plotly.express as px
import geopandas as gpd
import plotly.graph_objects as go
requests_cache.install_cache("fetch_fips")

# %%
url = 'https://raw.githubusercontent.com/plotly/datasets/master/geojson-counties-fips.json'

# %%
result = requests.get(url)
counties = json.loads(result.text)

# %%
px.set_mapbox_access_token(open("../../tools&keys/mapbox.txt").read())

# %% [markdown]
# We will use this map to further visualize the network performance by region between years.

# %% [markdown]
# # scrape the zip to get the fips

# %%
df = pd.read_csv('../data/measurement_test_2021-2023/2021_1.csv')

# %%
df.head(3)
# Out:
#      zip  throughput
# 0  95134   26.151214
# 1  94539   27.242447
# 2  95112   39.113374

# %%
len(df)
# Out:
# 100000

# %%
url = 'https://www.zipinfo.com/cgi-local/zipsrch.exe'

# %%
response = requests.get(url, params = {
        'cnty': 'cnty',
        'zip': 95616,
        'Go': 'Go'
})
response.raise_for_status()

# %%
html = lx.fromstring(response.text)

# %%
html.xpath('//table/tr[2]/td[last()]/text()')
# Out:
# ['06113', 'latitude and longitude']

# %%
html.xpath('//table/tr[2]/td[last()]/text()')[0].strip()
# Out:
# '06113'

# %%
def fetch_fips(zip):
    url = 'https://www.zipinfo.com/cgi-local/zipsrch.exe'
    params = {'cnty': 'cnty', 'zip': zip, 'Go': 'Go'}
    response = requests.get(url, params)
    if response.status_code != 200:
        return None

    html = lx.fromstring(response.text)
    fips = html.xpath('//table/tr[2]/td[last()]/text()')[0].strip()
    return fips

# %% [markdown]
# ### Since we only focus on california, the zip code is from 90000 to 96162, we want to form a mapping for further use to map zip code to fips code

# %%
zip_fips_mapping = {}

# %%
for zip in tqdm(range(90000, 96163)):
    fips = fetch_fips(zip)
    if fips:
        zip_fips_mapping[zip] = fips
    time.sleep(0.1)
# Out:
# 100%|███████████████████████████████████████████████████████████| 6163/6163 [35:22<00:00,  2.90it/s]

# %%
zip_fips_mapping
# Out:
# {90000: 'latitude and longitude',
#  90001: '06037',
#  90002: '06037',
#  90003: '06037',
#  90004: '06037',
#  90005: '06037',
#  90006: '06037',
#  90007: '06037',
#  90008: '06037',
#  90009: '06037',
#  90010: '06037',
#  90011: '06037',
#  90012: '06037',
#  90013: '06037',
#  90014: '06037',
#  90015: '06037',
#  90016: '06037',
#  90017: '06037',
#  90018: '06037',
#  90019: '06037',
#  90020: '06037',
#  90021: '06037',
#  90022: '06037',
#  90023: '06037',
#  90024: '06037',
#  90025: '06037',
#  90026: '06037',
#  90027: '06037',
#  90028: '06037',
#  90029: '06037',
#  90030: '06037',
#  90031: '06037',
#  90032: '06037',
#  90033: '06037',
#  90034: '06037',
#  90035: '06037',
#  90036: '06037',
#  90037: '06037',
#  90038: '06037',
#  90039: '06037',
#  90040: '06037',
#  90041: '06037',
#  90042: '06037',
#  90043: '06037',
#  90044: '06037',
#  90045: '06037',
#  90046: '06037',
#  90047: '06037',
#  90048: '06037',
#  90049: '06037',
#  90050: '06037',
#  90051: '06037',
#  90052: '06037',
#  90053: '06037',
#  90054: '06037',
#  90055: '06037',
#  90056: '06037',
#  90057: '06037',
#  90058: '06037',
#  90059: '06037',
#  90060: '06037',
#  90061: '06037',
#  90062: '06037',
#  90063: '06037',
#  90064: '06037',
#  90065: '06037',
#  90066: '06037',
#  90067: '06037',
#  90068: '06037',
#  90069: '06037',
#  90070: '06037',
#  90071: '06037',
#  90072: '06037',
#  90073: '06037',
#  90074: '06037',
#  90075: '06037',
#  90076: '06037',
#  90077: '06037',
#  90078: '06037',
#  90079: '06037',
#  90080: '06037',
#  90081: '06037',
#  90082: '06037',
#  90083: '06037',
#  90084: '06037',
#  90085: 'latitude and longitude',
#  90086: '06037',
#  90087: '06037',
#  90088: '06037',
#  90089: '06037',
#  90090: 'latitude and longitude',
#  90091: '06037',
#  90092: 'latitude and longitude',
#  90093: '06037',
#  90094: '06037',
#  90095: '06037',
#  90096: '06037',
#  90097: 'latitude and longitude',
#  90098: 'latitude and longitude',
#  90099: '06037',
#  90100: 'latitude and longitude',
#  90101: 'latitude and longitude',
#  90102: 'latitude and longitude',
#  90103: 'latitude and longitude',
#  90104: 'latitude and longitude',
#  90105: 'latitude and longitude',
#  90106: 'latitude and longitude',
#  90107: 'latitude and longitude',
#  90108: 'latitude and longitude',
#  90109: 'latitude and longitude',
#  90110: 'latitude and longitude',
#  90111: 'latitude and longitude',
#  90112: 'latitude and longitude',
#  90113: 'latitude and longitude',
#  90114: 'latitude and longitude',
#  90115: 'latitude and longitude',
#  90116: 'latitude and longitude',
#  90117: 'latitude and longitude',
#  90118: 'latitude and longitude',
#  90119: 'latitude and longitude',
#  90120: 'latitude and longitude',
#  90121: 'latitude and longitude',
#  90122: 'latitude and longitude',
#  90123: 'latitude and longitude',
#  90124: 'latitude and longitude',
#  90125: 'latitude and longitude',
#  90126: 'latitude and longitude',
#  90127: 'latitude and longitude',
#  90128: 'latitude and longitude',
#  90129: 'latitude and longitude',
#  90130: 'latitude and longitude',
#  90131: 'latitude and longitude',
#  90132: 'latitude and longitude',
#  90133: 'latitude and longitude',
#  90134: '06037',
#  90135: 'latitude and longitude',
#  90136: 'latitude and longitude',
#  90137: 'latitude and longitude',
#  90138: 'latitude and longitude',
#  90139: 'latitude and longitude',
#  90140: 'latitude and longitude',
#  90141: 'latitude and longitude',
#  90142: 'latitude and longitude',
#  90143: 'latitude and longitude',
#  90144: 'latitude and longitude',
#  90145: 'latitude and longitude',
#  90146: 'latitude and longitude',
#  90147: 'latitude and longitude',
#  90148: 'latitude and longitude',
#  90149: 'latitude and longitude',
#  90150: 'latitude and longitude',
#  90151: 'latitude and longitude',
#  90152: 'latitude and longitude',
#  90153: 'latitude and longitude',
#  90154: 'latitude and longitude',
#  90155: 'latitude and longitude',
#  90156: 'latitude and longitude',
#  90157: 'latitude and longitude',
#  90158: 'latitude and longitude',
#  90159: 'latitude and longitude',
#  90160: 'latitude and longitude',
#  90161: 'latitude and longitude',
#  90162: 'latitude and longitude',
#  90163: 'latitude and longitude',
#  90164: 'latitude and longitude',
#  90165: 'latitude and longitude',
#  90166: 'latitude and longitude',
#  90167: 'latitude and longitude',
#  90168: 'latitude and longitude',
#  90169: 'latitude and longitude',
#  90170: 'latitude and longitude',
#  90171: 'latitude and longitude',
#  90172: 'latitude and longitude',
#  90173: 'latitude and longitude',
#  90174: 'latitude and longitude',
#  90175: 'latitude and longitude',
#  90176: 'latitude and longitude',
#  90177: 'latitude and longitude',
#  90178: 'latitude and longitude',
#  90179: 'latitude and longitude',
#  90180: 'latitude and longitude',
#  90181: 'latitude and longitude',
#  90182: 'latitude and longitude',
#  90183: 'latitude and longitude',
#  90184: 'latitude and longitude',
#  90185: 'latitude and longitude',
#  90186: 'latitude and longitude',
#  90187: 'latitude and longitude',
#  90188: 'latitude and longitude',
#  90189: '06037',
#  90190: 'latitude and longitude',
#  90191: 'latitude and longitude',
#  90192: 'latitude and longitude',
#  90193: 'latitude and longitude',
#  90194: 'latitude and longitude',
#  90195: 'latitude and longitude',
#  90196: 'latitude and longitude',
#  90197: 'latitude and longitude',
#  90198: 'latitude and longitude',
#  90199: 'latitude and longitude',
#  90200: 'latitude and longitude',
#  90201: '06037',
#  90202: '06037',
#  90203: 'latitude and longitude',
#  90204: 'latitude and longitude',
#  90205: 'latitude and longitude',
#  90206: 'latitude and longitude',
#  90207: 'latitude and longitude',
#  90208: 'latitude and longitude',
#  90209: '06037',
#  90210: '06037',
#  90211: '06037',
#  90212: '06037',
#  90213: '06037',
#  90214: 'latitude and longitude',
#  90215: 'latitude and longitude',
#  90216: 'latitude and longitude',
#  90217: 'latitude and longitude',
#  90218: 'latitude and longitude',
#  90219: 'latitude and longitude',
#  90220: '06037',
#  90221: '06037',
#  90222: '06037',
#  90223: '06037',
#  90224: '06037',
#  90225: 'latitude and longitude',
#  90226: 'latitude and longitude',
#  90227: 'latitude and longitude',
#  90228: 'latitude and longitude',
#  90229: 'latitude and longitude',
#  90230: '06037',
#  90231: '06037',
#  90232: '06037',
#  90233: 'latitude and longitude',
#  90234: 'latitude and longitude',
#  90235: 'latitude and longitude',
#  90236: 'latitude and longitude',
#  90237: 'latitude and longitude',
#  90238: 'latitude and longitude',
#  90239: '06037',
#  90240: '06037',
#  90241: '06037',
#  90242: '06037',
#  90243: 'latitude and longitude',
#  90244: 'latitude and longitude',
#  90245: '06037',
#  90246: 'latitude and longitude',
#  90247: '06037',
#  90248: '06037',
#  90249: '06037',
#  90250: '06037',
#  90251: '06037',
#  90252: 'latitude and longitude',
#  90253: 'latitude and longitude',
#  90254: '06037',
#  90255: '06037',
#  90256: 'latitude and longitude',
#  90257: 'latitude and longitude',
#  90258: 'latitude and longitude',
#  90259: 'latitude and longitude',
#  90260: '06037',
#  90261: '06037',
#  90262: '06037',
#  90263: '06037',
#  90264: '06037',
#  90265: '06037',
#  90266: '06037',
#  90267: '06037',
#  90268: 'latitude and longitude',
#  90269: 'latitude and longitude',
#  90270: '06037',
#  90271: 'latitude and longitude',
#  90272: '06037',
#  90273: 'latitude and longitude',
#  90274: '06037',
#  90275: '06037',
#  90276: 'latitude and longitude',
#  90277: '06037',
#  90278: '06037',
#  90279: 'latitude and longitude',
#  90280: '06037',
#  90281: 'latitude and longitude',
#  90282: 'latitude and longitude',
#  90283: 'latitude and longitude',
#  90284: 'latitude and longitude',
#  90285: 'latitude and longitude',
#  90286: 'latitude and longitude',
#  90287: 'latitude and longitude',
#  90288: 'latitude and longitude',
#  90289: 'latitude and longitude',
#  90290: '06037',
#  90291: '06037',
#  90292: '06037',
#  90293: '06037',
#  90294: '06037',
#  90295: '06037',
#  90296: '06037',
#  90297: 'latitude and longitude',
#  90298: 'latitude and longitude',
#  90299: 'latitude and longitude',
#  90300: 'latitude and longitude',
#  90301: '06037',
#  90302: '06037',
#  90303: '06037',
#  90304: '06037',
#  90305: '06037',
#  90306: '06037',
#  90307: '06037',
#  90308: '06037',
#  90309: '06037',
#  90310: '06037',
#  90311: '06037',
#  90312: '06037',
#  90313: 'latitude and longitude',
#  90314: 'latitude and longitude',
#  90315: 'latitude and longitude',
#  90316: 'latitude and longitude',
#  90317: 'latitude and longitude',
#  90318: 'latitude and longitude',
#  90319: 'latitude and longitude',
#  90320: 'latitude and longitude',
#  90321: 'latitude and longitude',
#  90322: 'latitude and longitude',
#  90323: 'latitude and longitude',
#  90324: 'latitude and longitude',
#  90325: 'latitude and longitude',
#  90326: 'latitude and longitude',
#  90327: 'latitude and longitude',
#  90328: 'latitude and longitude',
#  90329: 'latitude and longitude',
#  90330: 'latitude and longitude',
#  90331: 'latitude and longitude',
#  90332: 'latitude and longitude',
#  90333: 'latitude and longitude',
#  90334: 'latitude and longitude',
#  90335: 'latitude and longitude',
#  90336: 'latitude and longitude',
#  90337: 'latitude and longitude',
#  90338: 'latitude and longitude',
#  90339: 'latitude and longitude',
#  90340: 'latitude and longitude',
#  90341: 'latitude and longitude',
#  90342: 'latitude and longitude',
#  90343: 'latitude and longitude',
#  90344: 'latitude and longitude',
#  90345: 'latitude and longitude',
#  90346: 'latitude and longitude',
#  90347: 'latitude and longitude',
#  90348: 'latitude and longitude',
#  90349: 'latitude and longitude',
#  90350: 'latitude and longitude',
#  90351: 'latitude and longitude',
#  90352: 'latitude and longitude',
#  90353: 'latitude and longitude',
#  90354: 'latitude and longitude',
#  90355: 'latitude and longitude',
#  90356: 'latitude and longitude',
#  90357: 'latitude and longitude',
#  90358: 'latitude and longitude',
#  90359: 'latitude and longitude',
#  90360: 'latitude and longitude',
#  90361: 'latitude and longitude',
#  90362: 'latitude and longitude',
#  90363: 'latitude and longitude',
#  90364: 'latitude and longitude',
#  90365: 'latitude and longitude',
#  90366: 'latitude and longitude',
#  90367: 'latitude and longitude',
#  90368: 'latitude and longitude',
#  90369: 'latitude and longitude',
#  90370: 'latitude and longitude',
#  90371: 'latitude and longitude',
#  90372: 'latitude and longitude',
#  90373: 'latitude and longitude',
#  90374: 'latitude and longitude',
#  90375: 'latitude and longitude',
#  90376: 'latitude and longitude',
#  90377: 'latitude and longitude',
#  90378: 'latitude and longitude',
#  90379: 'latitude and longitude',
#  90380: 'latitude and longitude',
#  90381: 'latitude and longitude',
#  90382: 'latitude and longitude',
#  90383: 'latitude and longitude',
#  90384: 'latitude and longitude',
#  90385: 'latitude and longitude',
#  90386: 'latitude and longitude',
#  90387: 'latitude and longitude',
#  90388: 'latitude and longitude',
#  90389: 'latitude and longitude',
#  90390: 'latitude and longitude',
#  90391: 'latitude and longitude',
#  90392: 'latitude and longitude',
#  90393: 'latitude and longitude',
#  90394: 'latitude and longitude',
#  90395: 'latitude and longitude',
#  90396: 'latitude and longitude',
#  90397: 'latitude and longitude',
#  90398: 'latitude and longitude',
#  90399: 'latitude and longitude',
#  90400: 'latitude and longitude',
#  90401: '06037',
#  90402: '06037',
#  90403: '06037',
#  90404: '06037',
#  90405: '06037',
#  90406: '06037',
#  90407: '06037',
#  90408: '06037',
#  90409: '06037',
#  90410: '06037',
#  90411: '06037',
#  90412: 'latitude and longitude',
#  90413: 'latitude and longitude',
#  90414: 'latitude and longitude',
#  90415: 'latitude and longitude',
#  90416: 'latitude and longitude',
#  90417: 'latitude and longitude',
#  90418: 'latitude and longitude',
#  90419: 'latitude and longitude',
#  90420: 'latitude and longitude',
#  90421: 'latitude and longitude',
#  90422: 'latitude and longitude',
#  90423: 'latitude and longitude',
#  90424: 'latitude and longitude',
#  90425: 'latitude and longitude',
#  90426: 'latitude and longitude',
#  90427: 'latitude and longitude',
#  90428: 'latitude and longitude',
#  90429: 'latitude and longitude',
#  90430: 'latitude and longitude',
#  90431: 'latitude and longitude',
#  90432: 'latitude and longitude',
#  90433: 'latitude and longitude',
#  90434: 'latitude and longitude',
#  90435: 'latitude and longitude',
#  90436: 'latitude and longitude',
#  90437: 'latitude and longitude',
#  90438: 'latitude and longitude',
#  90439: 'latitude and longitude',
#  90440: 'latitude and longitude',
#  90441: 'latitude and longitude',
#  90442: 'latitude and longitude',
#  90443: 'latitude and longitude',
#  90444: 'latitude and longitude',
#  90445: 'latitude and longitude',
#  90446: 'latitude and longitude',
#  90447: 'latitude and longitude',
#  90448: 'latitude and longitude',
#  90449: 'latitude and longitude',
#  90450: 'latitude and longitude',
#  90451: 'latitude and longitude',
#  90452: 'latitude and longitude',
#  90453: 'latitude and longitude',
#  90454: 'latitude and longitude',
#  90455: 'latitude and longitude',
#  90456: 'latitude and longitude',
#  90457: 'latitude and longitude',
#  90458: 'latitude and longitude',
#  90459: 'latitude and longitude',
#  90460: 'latitude and longitude',
#  90461: 'latitude and longitude',
#  90462: 'latitude and longitude',
#  90463: 'latitude and longitude',
#  90464: 'latitude and longitude',
#  90465: 'latitude and longitude',
#  90466: 'latitude and longitude',
#  90467: 'latitude and longitude',
#  90468: 'latitude and longitude',
#  90469: 'latitude and longitude',
#  90470: 'latitude and longitude',
#  90471: 'latitude and longitude',
#  90472: 'latitude and longitude',
#  90473: 'latitude and longitude',
#  90474: 'latitude and longitude',
#  90475: 'latitude and longitude',
#  90476: 'latitude and longitude',
#  90477: 'latitude and longitude',
#  90478: 'latitude and longitude',
#  90479: 'latitude and longitude',
#  90480: 'latitude and longitude',
#  90481: 'latitude and longitude',
#  90482: 'latitude and longitude',
#  90483: 'latitude and longitude',
#  90484: 'latitude and longitude',
#  90485: 'latitude and longitude',
#  90486: 'latitude and longitude',
#  90487: 'latitude and longitude',
#  90488: 'latitude and longitude',
#  90489: 'latitude and longitude',
#  90490: 'latitude and longitude',
#  90491: 'latitude and longitude',
#  90492: 'latitude and longitude',
#  90493: 'latitude and longitude',
#  90494: 'latitude and longitude',
#  90495: 'latitude and longitude',
#  90496: 'latitude and longitude',
#  90497: 'latitude and longitude',
#  90498: 'latitude and longitude',
#  90499: 'latitude and longitude',
#  90500: 'latitude and longitude',
#  90501: '06037',
#  90502: '06037',
#  90503: '06037',
#  90504: '06037',
#  90505: '06037',
#  90506: '06037',
#  90507: '06037',
#  90508: '06037',
#  90509: '06037',
#  90510: '06037',
#  90511: 'latitude and longitude',
#  90512: 'latitude and longitude',
#  90513: 'latitude and longitude',
#  90514: 'latitude and longitude',
#  90515: 'latitude and longitude',
#  90516: 'latitude and longitude',
#  90517: 'latitude and longitude',
#  90518: 'latitude and longitude',
#  90519: 'latitude and longitude',
#  90520: 'latitude and longitude',
#  90521: 'latitude and longitude',
#  90522: 'latitude and longitude',
#  90523: 'latitude and longitude',
#  90524: 'latitude and longitude',
#  90525: 'latitude and longitude',
#  90526: 'latitude and longitude',
#  90527: 'latitude and longitude',
#  90528: 'latitude and longitude',
#  90529: 'latitude and longitude',
#  90530: 'latitude and longitude',
#  90531: 'latitude and longitude',
#  90532: 'latitude and longitude',
#  90533: 'latitude and longitude',
#  90534: 'latitude and longitude',
#  90535: 'latitude and longitude',
#  90536: 'latitude and longitude',
#  90537: 'latitude and longitude',
#  90538: 'latitude and longitude',
#  90539: 'latitude and longitude',
#  90540: 'latitude and longitude',
#  90541: 'latitude and longitude',
#  90542: 'latitude and longitude',
#  90543: 'latitude and longitude',
#  90544: 'latitude and longitude',
#  90545: 'latitude and longitude',
#  90546: 'latitude and longitude',
#  90547: 'latitude and longitude',
#  90548: 'latitude and longitude',
#  90549: 'latitude and longitude',
#  90550: 'latitude and longitude',
#  90551: 'latitude and longitude',
#  90552: 'latitude and longitude',
#  90553: 'latitude and longitude',
#  90554: 'latitude and longitude',
#  90555: 'latitude and longitude',
#  90556: 'latitude and longitude',
#  90557: 'latitude and longitude',
#  90558: 'latitude and longitude',
#  90559: 'latitude and longitude',
#  90560: 'latitude and longitude',
#  90561: 'latitude and longitude',
#  90562: 'latitude and longitude',
#  90563: 'latitude and longitude',
#  90564: 'latitude and longitude',
#  90565: 'latitude and longitude',
#  90566: 'latitude and longitude',
#  90567: 'latitude and longitude',
#  90568: 'latitude and longitude',
#  90569: 'latitude and longitude',
#  90570: 'latitude and longitude',
#  90571: 'latitude and longitude',
#  90572: 'latitude and longitude',
#  90573: 'latitude and longitude',
#  90574: 'latitude and longitude',
#  90575: 'latitude and longitude',
#  90576: 'latitude and longitude',
#  90577: 'latitude and longitude',
#  90578: 'latitude and longitude',
#  90579: 'latitude and longitude',
#  90580: 'latitude and longitude',
#  90581: 'latitude and longitude',
#  90582: 'latitude and longitude',
#  90583: 'latitude and longitude',
#  90584: 'latitude and longitude',
#  90585: 'latitude and longitude',
#  90586: 'latitude and longitude',
#  90587: 'latitude and longitude',
#  90588: 'latitude and longitude',
#  90589: 'latitude and longitude',
#  90590: 'latitude and longitude',
#  90591: 'latitude and longitude',
#  90592: 'latitude and longitude',
#  90593: 'latitude and longitude',
#  90594: 'latitude and longitude',
#  90595: 'latitude and longitude',
#  90596: 'latitude and longitude',
#  90597: 'latitude and longitude',
#  90598: 'latitude and longitude',
#  90599: 'latitude and longitude',
#  90600: 'latitude and longitude',
#  90601: '06037',
#  90602: '06037',
#  90603: '06037',
#  90604: '06037',
#  90605: '06037',
#  90606: '06037',
#  90607: '06037',
#  90608: '06037',
#  90609: '06037',
#  90610: '06037',
#  90611: 'latitude and longitude',
#  90612: 'latitude and longitude',
#  90613: 'latitude and longitude',
#  90614: 'latitude and longitude',
#  90615: 'latitude and longitude',
#  90616: 'latitude and longitude',
#  90617: 'latitude and longitude',
#  90618: 'latitude and longitude',
#  90619: 'latitude and longitude',
#  90620: '06059',
#  90621: '06059',
#  90622: '06059',
#  90623: '06059',
#  90624: '06059',
#  90625: 'latitude and longitude',
#  90626: 'latitude and longitude',
#  90627: 'latitude and longitude',
#  90628: 'latitude and longitude',
#  90629: 'latitude and longitude',
#  90630: '06059',
#  90631: '06059',
#  90632: '06059',
#  90633: '06059',
#  90634: 'latitude and longitude',
#  90635: 'latitude and longitude',
#  90636: 'latitude and longitude',
#  90637: '06037',
#  90638: '06037',
#  90639: '06037',
#  90640: '06037',
#  90641: 'latitude and longitude',
#  90642: 'latitude and longitude',
#  90643: 'latitude and longitude',
#  90644: 'latitude and longitude',
#  90645: 'latitude and longitude',
#  90646: 'latitude and longitude',
#  90647: 'latitude and longitude',
#  90648: 'latitude and longitude',
#  90649: 'latitude and longitude',
#  90650: '06037',
#  90651: '06037',
#  90652: '06037',
#  90653: 'latitude and longitude',
#  90654: 'latitude and longitude',
#  90655: 'latitude and longitude',
#  90656: 'latitude and longitude',
#  90657: 'latitude and longitude',
#  90658: 'latitude and longitude',
#  90659: 'latitude and longitude',
#  90660: '06037',
#  90661: '06037',
#  90662: '06037',
#  90663: 'latitude and longitude',
#  90664: 'latitude and longitude',
#  90665: 'latitude and longitude',
#  90666: 'latitude and longitude',
#  90667: 'latitude and longitude',
#  90668: 'latitude and longitude',
#  90669: 'latitude and longitude',
#  90670: '06037',
#  90671: '06037',
#  90672: 'latitude and longitude',
#  90673: 'latitude and longitude',
#  90674: 'latitude and longitude',
#  90675: 'latitude and longitude',
#  90676: 'latitude and longitude',
#  90677: 'latitude and longitude',
#  90678: 'latitude and longitude',
#  90679: 'latitude and longitude',
#  90680: '06059',
#  90681: 'latitude and longitude',
#  90682: 'latitude and longitude',
#  90683: 'latitude and longitude',
#  90684: 'latitude and longitude',
#  90685: 'latitude and longitude',
#  90686: 'latitude and longitude',
#  90687: 'latitude and longitude',
#  90688: 'latitude and longitude',
#  90689: 'latitude and longitude',
#  90690: 'latitude and longitude',
#  90691: 'latitude and longitude',
#  90692: 'latitude and longitude',
#  90693: 'latitude and longitude',
#  90694: 'latitude and longitude',
#  90695: 'latitude and longitude',
#  90696: 'latitude and longitude',
#  90697: 'latitude and longitude',
#  90698: 'latitude and longitude',
#  90699: 'latitude and longitude',
#  90700: 'latitude and longitude',
#  90701: '06037',
#  90702: '06037',
#  90703: '06037',
#  90704: '06037',
#  90705: 'latitude and longitude',
#  90706: '06037',
#  90707: '06037',
#  90708: 'latitude and longitude',
#  90709: 'latitude and longitude',
#  90710: '06037',
#  90711: '06037',
#  90712: '06037',
#  90713: '06037',
#  90714: '06037',
#  90715: '06037',
#  90716: '06037',
#  90717: '06037',
#  90718: 'latitude and longitude',
#  90719: 'latitude and longitude',
#  90720: '06059',
#  90721: '06059',
#  90722: 'latitude and longitude',
#  90723: '06037',
#  90724: 'latitude and longitude',
#  90725: 'latitude and longitude',
#  90726: 'latitude and longitude',
#  90727: 'latitude and longitude',
#  90728: 'latitude and longitude',
#  90729: 'latitude and longitude',
#  90730: 'latitude and longitude',
#  90731: '06037',
#  90732: '06037',
#  90733: '06037',
#  90734: '06037',
#  90735: 'latitude and longitude',
#  90736: 'latitude and longitude',
#  90737: 'latitude and longitude',
#  90738: 'latitude and longitude',
#  90739: 'latitude and longitude',
#  90740: '06059',
#  90741: 'latitude and longitude',
#  90742: '06059',
#  90743: '06059',
#  90744: '06037',
#  90745: '06037',
#  90746: '06037',
#  90747: '06037',
#  90748: '06037',
#  90749: '06037',
#  90750: 'latitude and longitude',
#  90751: 'latitude and longitude',
#  90752: 'latitude and longitude',
#  90753: 'latitude and longitude',
#  90754: 'latitude and longitude',
#  90755: '06037',
#  90756: 'latitude and longitude',
#  90757: 'latitude and longitude',
#  90758: 'latitude and longitude',
#  90759: 'latitude and longitude',
#  90760: 'latitude and longitude',
#  90761: 'latitude and longitude',
#  90762: 'latitude and longitude',
#  90763: 'latitude and longitude',
#  90764: 'latitude and longitude',
#  90765: 'latitude and longitude',
#  90766: 'latitude and longitude',
#  90767: 'latitude and longitude',
#  90768: 'latitude and longitude',
#  90769: 'latitude and longitude',
#  90770: 'latitude and longitude',
#  90771: 'latitude and longitude',
#  90772: 'latitude and longitude',
#  90773: 'latitude and longitude',
#  90774: 'latitude and longitude',
#  90775: 'latitude and longitude',
#  90776: 'latitude and longitude',
#  90777: 'latitude and longitude',
#  90778: 'latitude and longitude',
#  90779: 'latitude and longitude',
#  90780: 'latitude and longitude',
#  90781: 'latitude and longitude',
#  90782: 'latitude and longitude',
#  90783: 'latitude and longitude',
#  90784: 'latitude and longitude',
#  90785: 'latitude and longitude',
#  90786: 'latitude and longitude',
#  90787: 'latitude and longitude',
#  90788: 'latitude and longitude',
#  90789: 'latitude and longitude',
#  90790: 'latitude and longitude',
#  90791: 'latitude and longitude',
#  90792: 'latitude and longitude',
#  90793: 'latitude and longitude',
#  90794: 'latitude and longitude',
#  90795: 'latitude and longitude',
#  90796: 'latitude and longitude',
#  90797: 'latitude and longitude',
#  90798: 'latitude and longitude',
#  90799: 'latitude and longitude',
#  90800: 'latitude and longitude',
#  90801: '06037',
#  90802: '06037',
#  90803: '06037',
#  90804: '06037',
#  90805: '06037',
#  90806: '06037',
#  90807: '06037',
#  90808: '06037',
#  90809: '06037',
#  90810: '06037',
#  90811: 'latitude and longitude',
#  90812: 'latitude and longitude',
#  90813: '06037',
#  90814: '06037',
#  90815: '06037',
#  90816: 'latitude and longitude',
#  90817: 'latitude and longitude',
#  90818: 'latitude and longitude',
#  90819: 'latitude and longitude',
#  90820: 'latitude and longitude',
#  90821: 'latitude and longitude',
#  90822: '06037',
#  90823: 'latitude and longitude',
#  90824: 'latitude and longitude',
#  90825: 'latitude and longitude',
#  90826: 'latitude and longitude',
#  90827: 'latitude and longitude',
#  90828: 'latitude and longitude',
#  90829: 'latitude and longitude',
#  90830: 'latitude and longitude',
#  90831: '06037',
#  90832: '06037',
#  90833: '06037',
#  90834: 'latitude and longitude',
#  90835: 'latitude and longitude',
#  90836: 'latitude and longitude',
#  90837: 'latitude and longitude',
#  90838: 'latitude and longitude',
#  90839: 'latitude and longitude',
#  90840: '06037',
#  90841: 'latitude and longitude',
#  90842: '06037',
#  90843: 'latitude and longitude',
#  90844: '06037',
#  90845: 'latitude and longitude',
#  90846: '06037',
#  90847: '06037',
#  90848: '06037',
#  90849: 'latitude and longitude',
#  90850: 'latitude and longitude',
#  90851: 'latitude and longitude',
#  90852: 'latitude and longitude',
#  90853: '06037',
#  90854: 'latitude and longitude',
#  90855: 'latitude and longitude',
#  90856: 'latitude and longitude',
#  90857: 'latitude and longitude',
#  90858: 'latitude and longitude',
#  90859: 'latitude and longitude',
#  90860: 'latitude and longitude',
#  90861: 'latitude and longitude',
#  90862: 'latitude and longitude',
#  90863: 'latitude and longitude',
#  90864: 'latitude and longitude',
#  90865: 'latitude and longitude',
#  90866: 'latitude and longitude',
#  90867: 'latitude and longitude',
#  90868: 'latitude and longitude',
#  90869: 'latitude and longitude',
#  90870: 'latitude and longitude',
#  90871: 'latitude and longitude',
#  90872: 'latitude and longitude',
#  90873: 'latitude and longitude',
#  90874: 'latitude and longitude',
#  90875: 'latitude and longitude',
#  90876: 'latitude and longitude',
#  90877: 'latitude and longitude',
#  90878: 'latitude and longitude',
#  90879: 'latitude and longitude',
#  90880: 'latitude and longitude',
#  90881: 'latitude and longitude',
#  90882: 'latitude and longitude',
#  90883: 'latitude and longitude',
#  90884: 'latitude and longitude',
#  90885: 'latitude and longitude',
#  90886: 'latitude and longitude',
#  90887: 'latitude and longitude',
#  90888: 'latitude and longitude',
#  90889: 'latitude and longitude',
#  90890: 'latitude and longitude',
#  90891: 'latitude and longitude',
#  90892: 'latitude and longitude',
#  90893: 'latitude and longitude',
#  90894: 'latitude and longitude',
#  90895: '06037',
#  90896: 'latitude and longitude',
#  90897: 'latitude and longitude',
#  90898: 'latitude and longitude',
#  90899: 'latitude and longitude',
#  90900: 'latitude and longitude',
#  90901: 'latitude and longitude',
#  90902: 'latitude and longitude',
#  90903: 'latitude and longitude',
#  90904: 'latitude and longitude',
#  90905: 'latitude and longitude',
#  90906: 'latitude and longitude',
#  90907: 'latitude and longitude',
#  90908: 'latitude and longitude',
#  90909: 'latitude and longitude',
#  90910: 'latitude and longitude',
#  90911: 'latitude and longitude',
#  90912: 'latitude and longitude',
#  90913: 'latitude and longitude',
#  90914: 'latitude and longitude',
#  90915: 'latitude and longitude',
#  90916: 'latitude and longitude',
#  90917: 'latitude and longitude',
#  90918: 'latitude and longitude',
#  90919: 'latitude and longitude',
#  90920: 'latitude and longitude',
#  90921: 'latitude and longitude',
#  90922: 'latitude and longitude',
#  90923: 'latitude and longitude',
#  90924: 'latitude and longitude',
#  90925: 'latitude and longitude',
#  90926: 'latitude and longitude',
#  90927: 'latitude and longitude',
#  90928: 'latitude and longitude',
#  90929: 'latitude and longitude',
#  90930: 'latitude and longitude',
#  90931: 'latitude and longitude',
#  90932: 'latitude and longitude',
#  90933: 'latitude and longitude',
#  90934: 'latitude and longitude',
#  90935: 'latitude and longitude',
#  90936: 'latitude and longitude',
#  90937: 'latitude and longitude',
#  90938: 'latitude and longitude',
#  90939: 'latitude and longitude',
#  90940: 'latitude and longitude',
#  90941: 'latitude and longitude',
#  90942: 'latitude and longitude',
#  90943: 'latitude and longitude',
#  90944: 'latitude and longitude',
#  90945: 'latitude and longitude',
#  90946: 'latitude and longitude',
#  90947: 'latitude and longitude',
#  90948: 'latitude and longitude',
#  90949: 'latitude and longitude',
#  90950: 'latitude and longitude',
#  90951: 'latitude and longitude',
#  90952: 'latitude and longitude',
#  90953: 'latitude and longitude',
#  90954: 'latitude and longitude',
#  90955: 'latitude and longitude',
#  90956: 'latitude and longitude',
#  90957: 'latitude and longitude',
#  90958: 'latitude and longitude',
#  90959: 'latitude and longitude',
#  90960: 'latitude and longitude',
#  90961: 'latitude and longitude',
#  90962: 'latitude and longitude',
#  90963: 'latitude and longitude',
#  90964: 'latitude and longitude',
#  90965: 'latitude and longitude',
#  90966: 'latitude and longitude',
#  90967: 'latitude and longitude',
#  90968: 'latitude and longitude',
#  90969: 'latitude and longitude',
#  90970: 'latitude and longitude',
#  90971: 'latitude and longitude',
#  90972: 'latitude and longitude',
#  90973: 'latitude and longitude',
#  90974: 'latitude and longitude',
#  90975: 'latitude and longitude',
#  90976: 'latitude and longitude',
#  90977: 'latitude and longitude',
#  90978: 'latitude and longitude',
#  90979: 'latitude and longitude',
#  90980: 'latitude and longitude',
#  90981: 'latitude and longitude',
#  90982: 'latitude and longitude',
#  90983: 'latitude and longitude',
#  90984: 'latitude and longitude',
#  90985: 'latitude and longitude',
#  90986: 'latitude and longitude',
#  90987: 'latitude and longitude',
#  90988: 'latitude and longitude',
#  90989: 'latitude and longitude',
#  90990: 'latitude and longitude',
#  90991: 'latitude and longitude',
#  90992: 'latitude and longitude',
#  90993: 'latitude and longitude',
#  90994: 'latitude and longitude',
#  90995: 'latitude and longitude',
#  90996: 'latitude and longitude',
#  90997: 'latitude and longitude',
#  90998: 'latitude and longitude',
#  90999: 'latitude and longitude',
#  ...}

# %%
a = 5
for k,v in zip_fips_mapping.items():
    print(k, " ", v, " ", len(v))
    a = a - 1
    if a == 0:
        break
# Out:
# 90000   latitude and longitude   22
# 90001   06037   5
# 90002   06037   5
# 90003   06037   5
# 90004   06037   5

# %%
zip_fips_mapping = {k: v for k,v in zip_fips_mapping.items() if len(v) == 5}
zip_fips_mapping
# Out:
# {90001: '06037',
#  90002: '06037',
#  90003: '06037',
#  90004: '06037',
#  90005: '06037',
#  90006: '06037',
#  90007: '06037',
#  90008: '06037',
#  90009: '06037',
#  90010: '06037',
#  90011: '06037',
#  90012: '06037',
#  90013: '06037',
#  90014: '06037',
#  90015: '06037',
#  90016: '06037',
#  90017: '06037',
#  90018: '06037',
#  90019: '06037',
#  90020: '06037',
#  90021: '06037',
#  90022: '06037',
#  90023: '06037',
#  90024: '06037',
#  90025: '06037',
#  90026: '06037',
#  90027: '06037',
#  90028: '06037',
#  90029: '06037',
#  90030: '06037',
#  90031: '06037',
#  90032: '06037',
#  90033: '06037',
#  90034: '06037',
#  90035: '06037',
#  90036: '06037',
#  90037: '06037',
#  90038: '06037',
#  90039: '06037',
#  90040: '06037',
#  90041: '06037',
#  90042: '06037',
#  90043: '06037',
#  90044: '06037',
#  90045: '06037',
#  90046: '06037',
#  90047: '06037',
#  90048: '06037',
#  90049: '06037',
#  90050: '06037',
#  90051: '06037',
#  90052: '06037',
#  90053: '06037',
#  90054: '06037',
#  90055: '06037',
#  90056: '06037',
#  90057: '06037',
#  90058: '06037',
#  90059: '06037',
#  90060: '06037',
#  90061: '06037',
#  90062: '06037',
#  90063: '06037',
#  90064: '06037',
#  90065: '06037',
#  90066: '06037',
#  90067: '06037',
#  90068: '06037',
#  90069: '06037',
#  90070: '06037',
#  90071: '06037',
#  90072: '06037',
#  90073: '06037',
#  90074: '06037',
#  90075: '06037',
#  90076: '06037',
#  90077: '06037',
#  90078: '06037',
#  90079: '06037',
#  90080: '06037',
#  90081: '06037',
#  90082: '06037',
#  90083: '06037',
#  90084: '06037',
#  90086: '06037',
#  90087: '06037',
#  90088: '06037',
#  90089: '06037',
#  90091: '06037',
#  90093: '06037',
#  90094: '06037',
#  90095: '06037',
#  90096: '06037',
#  90099: '06037',
#  90134: '06037',
#  90189: '06037',
#  90201: '06037',
#  90202: '06037',
#  90209: '06037',
#  90210: '06037',
#  90211: '06037',
#  90212: '06037',
#  90213: '06037',
#  90220: '06037',
#  90221: '06037',
#  90222: '06037',
#  90223: '06037',
#  90224: '06037',
#  90230: '06037',
#  90231: '06037',
#  90232: '06037',
#  90239: '06037',
#  90240: '06037',
#  90241: '06037',
#  90242: '06037',
#  90245: '06037',
#  90247: '06037',
#  90248: '06037',
#  90249: '06037',
#  90250: '06037',
#  90251: '06037',
#  90254: '06037',
#  90255: '06037',
#  90260: '06037',
#  90261: '06037',
#  90262: '06037',
#  90263: '06037',
#  90264: '06037',
#  90265: '06037',
#  90266: '06037',
#  90267: '06037',
#  90270: '06037',
#  90272: '06037',
#  90274: '06037',
#  90275: '06037',
#  90277: '06037',
#  90278: '06037',
#  90280: '06037',
#  90290: '06037',
#  90291: '06037',
#  90292: '06037',
#  90293: '06037',
#  90294: '06037',
#  90295: '06037',
#  90296: '06037',
#  90301: '06037',
#  90302: '06037',
#  90303: '06037',
#  90304: '06037',
#  90305: '06037',
#  90306: '06037',
#  90307: '06037',
#  90308: '06037',
#  90309: '06037',
#  90310: '06037',
#  90311: '06037',
#  90312: '06037',
#  90401: '06037',
#  90402: '06037',
#  90403: '06037',
#  90404: '06037',
#  90405: '06037',
#  90406: '06037',
#  90407: '06037',
#  90408: '06037',
#  90409: '06037',
#  90410: '06037',
#  90411: '06037',
#  90501: '06037',
#  90502: '06037',
#  90503: '06037',
#  90504: '06037',
#  90505: '06037',
#  90506: '06037',
#  90507: '06037',
#  90508: '06037',
#  90509: '06037',
#  90510: '06037',
#  90601: '06037',
#  90602: '06037',
#  90603: '06037',
#  90604: '06037',
#  90605: '06037',
#  90606: '06037',
#  90607: '06037',
#  90608: '06037',
#  90609: '06037',
#  90610: '06037',
#  90620: '06059',
#  90621: '06059',
#  90622: '06059',
#  90623: '06059',
#  90624: '06059',
#  90630: '06059',
#  90631: '06059',
#  90632: '06059',
#  90633: '06059',
#  90637: '06037',
#  90638: '06037',
#  90639: '06037',
#  90640: '06037',
#  90650: '06037',
#  90651: '06037',
#  90652: '06037',
#  90660: '06037',
#  90661: '06037',
#  90662: '06037',
#  90670: '06037',
#  90671: '06037',
#  90680: '06059',
#  90701: '06037',
#  90702: '06037',
#  90703: '06037',
#  90704: '06037',
#  90706: '06037',
#  90707: '06037',
#  90710: '06037',
#  90711: '06037',
#  90712: '06037',
#  90713: '06037',
#  90714: '06037',
#  90715: '06037',
#  90716: '06037',
#  90717: '06037',
#  90720: '06059',
#  90721: '06059',
#  90723: '06037',
#  90731: '06037',
#  90732: '06037',
#  90733: '06037',
#  90734: '06037',
#  90740: '06059',
#  90742: '06059',
#  90743: '06059',
#  90744: '06037',
#  90745: '06037',
#  90746: '06037',
#  90747: '06037',
#  90748: '06037',
#  90749: '06037',
#  90755: '06037',
#  90801: '06037',
#  90802: '06037',
#  90803: '06037',
#  90804: '06037',
#  90805: '06037',
#  90806: '06037',
#  90807: '06037',
#  90808: '06037',
#  90809: '06037',
#  90810: '06037',
#  90813: '06037',
#  90814: '06037',
#  90815: '06037',
#  90822: '06037',
#  90831: '06037',
#  90832: '06037',
#  90833: '06037',
#  90840: '06037',
#  90842: '06037',
#  90844: '06037',
#  90846: '06037',
#  90847: '06037',
#  90848: '06037',
#  90853: '06037',
#  90895: '06037',
#  91001: '06037',
#  91003: '06037',
#  91006: '06037',
#  91007: '06037',
#  91008: '06037',
#  91009: '06037',
#  91010: '06037',
#  91011: '06037',
#  91012: '06037',
#  91016: '06037',
#  91017: '06037',
#  91020: '06037',
#  91021: '06037',
#  91023: '06037',
#  91024: '06037',
#  91025: '06037',
#  91030: '06037',
#  91031: '06037',
#  91040: '06037',
#  91041: '06037',
#  91042: '06037',
#  91043: '06037',
#  91046: '06037',
#  91066: '06037',
#  91077: '06037',
#  91101: '06037',
#  91102: '06037',
#  91103: '06037',
#  91104: '06037',
#  91105: '06037',
#  91106: '06037',
#  91107: '06037',
#  91108: '06037',
#  91109: '06037',
#  91110: '06037',
#  91114: '06037',
#  91115: '06037',
#  91116: '06037',
#  91117: '06037',
#  91118: '06037',
#  91121: '06037',
#  91123: '06037',
#  91124: '06037',
#  91125: '06037',
#  91126: '06037',
#  91129: '06037',
#  91182: '06037',
#  91184: '06037',
#  91185: '06037',
#  91188: '06037',
#  91189: '06037',
#  91199: '06037',
#  91201: '06037',
#  91202: '06037',
#  91203: '06037',
#  91204: '06037',
#  91205: '06037',
#  91206: '06037',
#  91207: '06037',
#  91208: '06037',
#  91209: '06037',
#  91210: '06037',
#  91214: '06037',
#  91221: '06037',
#  91222: '06037',
#  91224: '06037',
#  91225: '06037',
#  91226: '06037',
#  91301: '06037',
#  91302: '06037',
#  91303: '06037',
#  91304: '06037',
#  91305: '06037',
#  91306: '06037',
#  91307: '06037',
#  91308: '06037',
#  91309: '06037',
#  91310: '06037',
#  91311: '06037',
#  91313: '06037',
#  91316: '06037',
#  91319: '06111',
#  91320: '06111',
#  91321: '06037',
#  91322: '06037',
#  91324: '06037',
#  91325: '06037',
#  91326: '06037',
#  91327: '06037',
#  91328: '06037',
#  91329: '06037',
#  91330: '06037',
#  91331: '06037',
#  91333: '06037',
#  91334: '06037',
#  91335: '06037',
#  91337: '06037',
#  91340: '06037',
#  91341: '06037',
#  91342: '06037',
#  91343: '06037',
#  91344: '06037',
#  91345: '06037',
#  91346: '06037',
#  91350: '06037',
#  91351: '06037',
#  91352: '06037',
#  91353: '06037',
#  91354: '06037',
#  91355: '06037',
#  91356: '06037',
#  91357: '06037',
#  91358: '06111',
#  91359: '06111',
#  91360: '06111',
#  91361: '06111',
#  91362: '06111',
#  91364: '06037',
#  91365: '06037',
#  91367: '06037',
#  91371: '06037',
#  91372: '06037',
#  91376: '06037',
#  91377: '06111',
#  91380: '06037',
#  91381: '06037',
#  91382: '06037',
#  91383: '06037',
#  91384: '06037',
#  91385: '06037',
#  91386: '06037',
#  91387: '06037',
#  91390: '06037',
#  91392: '06037',
#  91393: '06037',
#  91394: '06037',
#  91395: '06037',
#  91396: '06037',
#  91401: '06037',
#  91402: '06037',
#  91403: '06037',
#  91404: '06037',
#  91405: '06037',
#  91406: '06037',
#  91407: '06037',
#  91408: '06037',
#  91409: '06037',
#  91410: '06037',
#  91411: '06037',
#  91412: '06037',
#  91413: '06037',
#  91416: '06037',
#  91423: '06037',
#  91426: '06037',
#  91436: '06037',
#  91470: '06037',
#  91482: '06037',
#  91495: '06037',
#  91496: '06037',
#  91499: '06037',
#  91501: '06037',
#  91502: '06037',
#  91503: '06037',
#  91504: '06037',
#  91505: '06037',
#  91506: '06037',
#  91507: '06037',
#  91508: '06037',
#  91510: '06037',
#  91521: '06037',
#  91522: '06037',
#  91523: '06037',
#  91526: '06037',
#  91601: '06037',
#  91602: '06037',
#  91603: '06037',
#  91604: '06037',
#  91605: '06037',
#  91606: '06037',
#  91607: '06037',
#  91608: '06037',
#  91609: '06037',
#  91610: '06037',
#  91611: '06037',
#  91612: '06037',
#  91614: '06037',
#  91615: '06037',
#  91616: '06037',
#  91617: '06037',
#  91618: '06037',
#  91701: '06071',
#  91702: '06037',
#  91706: '06037',
#  91708: '06071',
#  91709: '06071',
#  91710: '06071',
#  91711: '06037',
#  91714: '06037',
#  91715: '06037',
#  91716: '06037',
#  91722: '06037',
#  91723: '06037',
#  91724: '06037',
#  91729: '06071',
#  91730: '06071',
#  91731: '06037',
#  91732: '06037',
#  91733: '06037',
#  91734: '06037',
#  91735: '06037',
#  91737: '06071',
#  91739: '06071',
#  91740: '06037',
#  91741: '06037',
#  91743: '06071',
#  91744: '06037',
#  91745: '06037',
#  91746: '06037',
#  91747: '06037',
#  91748: '06037',
#  91749: '06037',
#  91750: '06037',
#  91752: '06065',
#  91754: '06037',
#  91755: '06037',
#  91756: '06037',
#  91758: '06071',
#  91759: '06037',
#  91761: '06071',
#  91762: '06071',
#  91763: '06071',
#  91764: '06071',
#  91765: '06037',
#  91766: '06037',
#  91767: '06037',
#  91768: '06037',
#  91769: '06037',
#  91770: '06037',
#  91771: '06037',
#  91772: '06037',
#  91773: '06037',
#  91775: '06037',
#  91776: '06037',
#  91778: '06037',
#  91780: '06037',
#  91784: '06071',
#  91785: '06071',
#  91786: '06071',
#  91788: '06037',
#  91789: '06037',
#  91790: '06037',
#  91791: '06037',
#  91792: '06037',
#  91793: '06037',
#  91801: '06037',
#  91802: '06037',
#  91803: '06037',
#  91804: '06037',
#  91896: '06037',
#  91899: '06037',
#  91901: '06073',
#  91902: '06073',
#  91903: '06073',
#  91905: '06073',
#  91906: '06073',
#  91908: '06073',
#  91909: '06073',
#  91910: '06073',
#  91911: '06073',
#  91912: '06073',
#  91913: '06073',
#  91914: '06073',
#  91915: '06073',
#  91916: '06073',
#  91917: '06073',
#  91921: '06073',
#  91931: '06073',
#  91932: '06073',
#  91933: '06073',
#  91934: '06073',
#  91935: '06073',
#  91941: '06073',
#  91942: '06073',
#  91943: '06073',
#  91944: '06073',
#  91945: '06073',
#  91946: '06073',
#  91948: '06073',
#  91950: '06073',
#  91951: '06073',
#  91962: '06073',
#  91963: '06073',
#  91976: '06073',
#  91977: '06073',
#  91978: '06073',
#  91979: '06073',
#  91980: '06073',
#  91987: '06073',
#  92003: '06073',
#  92004: '06073',
#  92007: '06073',
#  92008: '06073',
#  92009: '06073',
#  92010: '06073',
#  92011: '06073',
#  92013: '06073',
#  92014: '06073',
#  92018: '06073',
#  92019: '06073',
#  92020: '06073',
#  92021: '06073',
#  92022: '06073',
#  92023: '06073',
#  92024: '06073',
#  92025: '06073',
#  92026: '06073',
#  92027: '06073',
#  92028: '06073',
#  92029: '06073',
#  92030: '06073',
#  92033: '06073',
#  92036: '06073',
#  92037: '06073',
#  92038: '06073',
#  92039: '06073',
#  92040: '06073',
#  92046: '06073',
#  92049: '06073',
#  92051: '06073',
#  92052: '06073',
#  92054: '06073',
#  92055: '06073',
#  92056: '06073',
#  92057: '06073',
#  92058: '06073',
#  92059: '06073',
#  92060: '06073',
#  92061: '06073',
#  92064: '06073',
#  92065: '06073',
#  92066: '06073',
#  92067: '06073',
#  92068: '06073',
#  92069: '06073',
#  92070: '06073',
#  92071: '06073',
#  92072: '06073',
#  92074: '06073',
#  92075: '06073',
#  92078: '06073',
#  92079: '06073',
#  92081: '06073',
#  92082: '06073',
#  92083: '06073',
#  92084: '06073',
#  92085: '06073',
#  92086: '06073',
#  92088: '06073',
#  92091: '06073',
#  92092: '06073',
#  92093: '06073',
#  92096: '06073',
#  92101: '06073',
#  92102: '06073',
#  92103: '06073',
#  92104: '06073',
#  92105: '06073',
#  92106: '06073',
#  92107: '06073',
#  92108: '06073',
#  92109: '06073',
#  92110: '06073',
#  92111: '06073',
#  92112: '06073',
#  92113: '06073',
#  92114: '06073',
#  92115: '06073',
#  92116: '06073',
#  92117: '06073',
#  92118: '06073',
#  92119: '06073',
#  92120: '06073',
#  92121: '06073',
#  92122: '06073',
#  92123: '06073',
#  92124: '06073',
#  92126: '06073',
#  92127: '06073',
#  92128: '06073',
#  92129: '06073',
#  92130: '06073',
#  92131: '06073',
#  92132: '06073',
#  92134: '06073',
#  92135: '06073',
#  92136: '06073',
#  92137: '06073',
#  92138: '06073',
#  92139: '06073',
#  92140: '06073',
#  92142: '06073',
#  92143: '06073',
#  92145: '06073',
#  92147: '06073',
#  92149: '06073',
#  92150: '06073',
#  92152: '06073',
#  92153: '06073',
#  92154: '06073',
#  92155: '06073',
#  92158: '06073',
#  92159: '06073',
#  92160: '06073',
#  92161: '06073',
#  92163: '06073',
#  92165: '06073',
#  92166: '06073',
#  92167: '06073',
#  92168: '06073',
#  92169: '06073',
#  92170: '06073',
#  92171: '06073',
#  92172: '06073',
#  92173: '06073',
#  92174: '06073',
#  92175: '06073',
#  92176: '06073',
#  92177: '06073',
#  92178: '06073',
#  92179: '06073',
#  92182: '06073',
#  92186: '06073',
#  92187: '06073',
#  92191: '06073',
#  92192: '06073',
#  92193: '06073',
#  92195: '06073',
#  92196: '06073',
#  92197: '06073',
#  92198: '06073',
#  92199: '06073',
#  92201: '06065',
#  92202: '06065',
#  92203: '06065',
#  92210: '06065',
#  92211: '06065',
#  92220: '06065',
#  92222: '06025',
#  92223: '06065',
#  92225: '06065',
#  92226: '06065',
#  92227: '06025',
#  92230: '06065',
#  92231: '06025',
#  92232: '06025',
#  92233: '06025',
#  92234: '06065',
#  92235: '06065',
#  92236: '06065',
#  92239: '06065',
#  92240: '06065',
#  92241: '06065',
#  92242: '06071',
#  92243: '06025',
#  92244: '06025',
#  92247: '06065',
#  92248: '06065',
#  92249: '06025',
#  92250: '06025',
#  92251: '06025',
#  92252: '06071',
#  92253: '06065',
#  92254: '06065',
#  92255: '06065',
#  92256: '06071',
#  92257: '06025',
#  92258: '06065',
#  92259: '06025',
#  92260: '06065',
#  92261: '06065',
#  92262: '06065',
#  92263: '06065',
#  92264: '06065',
#  92266: '06025',
#  92267: '06071',
#  92268: '06071',
#  92270: '06065',
#  92273: '06025',
#  92274: '06065',
#  92275: '06025',
#  92276: '06065',
#  92277: '06071',
#  92278: '06071',
#  92280: '06071',
#  92281: '06025',
#  92282: '06065',
#  92283: '06025',
#  92284: '06071',
#  92285: '06071',
#  92286: '06071',
#  92301: '06071',
#  92304: '06071',
#  92305: '06071',
#  92307: '06071',
#  92308: '06071',
#  92309: '06071',
#  92310: '06071',
#  92311: '06071',
#  92312: '06071',
#  92313: '06071',
#  92314: '06071',
#  92315: '06071',
#  92316: '06071',
#  92317: '06071',
#  92318: '06071',
#  92320: '06065',
#  92321: '06071',
#  92322: '06071',
#  92323: '06071',
#  92324: '06071',
#  92325: '06071',
#  92327: '06071',
#  92328: '06027',
#  92329: '06071',
#  92331: '06071',
#  92332: '06071',
#  92333: '06071',
#  92334: '06071',
#  92335: '06071',
#  92336: '06071',
#  92337: '06071',
#  92338: '06071',
#  92339: '06071',
#  92340: '06071',
#  92341: '06071',
#  92342: '06071',
#  92344: '06071',
#  92345: '06071',
#  92346: '06071',
#  92347: '06071',
#  92350: '06071',
#  92352: '06071',
#  92354: '06071',
#  92356: '06071',
#  92357: '06071',
#  92358: '06071',
#  92359: '06071',
#  92363: '06071',
#  92364: '06071',
#  92365: '06071',
#  92366: '06071',
#  92368: '06071',
#  92369: '06071',
#  92371: '06071',
#  92372: '06071',
#  92373: '06071',
#  92374: '06071',
#  92375: '06071',
#  92376: '06071',
#  92377: '06071',
#  92378: '06071',
#  92382: '06071',
#  92384: '06027',
#  92385: '06071',
#  92386: '06071',
#  92389: '06027',
#  92391: '06071',
#  92392: '06071',
#  92393: '06071',
#  92394: '06071',
#  92395: '06071',
#  92397: '06071',
#  92398: '06071',
#  92399: '06071',
#  92401: '06071',
#  92402: '06071',
#  92403: '06071',
#  92404: '06071',
#  92405: '06071',
#  92406: '06071',
#  92407: '06071',
#  92408: '06071',
#  92410: '06071',
#  92411: '06071',
#  92413: '06071',
#  92415: '06071',
#  92418: '06071',
#  92423: '06071',
#  92427: '06071',
#  92501: '06065',
#  92502: '06065',
#  92503: '06065',
#  92504: '06065',
#  92505: '06065',
#  92506: '06065',
#  92507: '06065',
#  92508: '06065',
#  92509: '06065',
#  92513: '06065',
#  92514: '06065',
#  92516: '06065',
#  92517: '06065',
#  92518: '06065',
#  92519: '06065',
#  92521: '06065',
#  92522: '06065',
#  92530: '06065',
#  92531: '06065',
#  92532: '06065',
#  92536: '06065',
#  92539: '06065',
#  92543: '06065',
#  92544: '06065',
#  92545: '06065',
#  92546: '06065',
#  92548: '06065',
#  92549: '06065',
#  92551: '06065',
#  92552: '06065',
#  92553: '06065',
#  92554: '06065',
#  92555: '06065',
#  92556: '06065',
#  92557: '06065',
#  92561: '06065',
#  92562: '06065',
#  92563: '06065',
#  92564: '06065',
#  92567: '06065',
#  92570: '06065',
#  92571: '06065',
#  92572: '06065',
#  92581: '06065',
#  92582: '06065',
#  92583: '06065',
#  92584: '06065',
#  92585: '06065',
#  92586: '06065',
#  92587: '06065',
#  92589: '06065',
#  92590: '06065',
#  92591: '06065',
#  92592: '06065',
#  92593: '06065',
#  92595: '06065',
#  92596: '06065',
#  92599: '06065',
#  92602: '06059',
#  92603: '06059',
#  92604: '06059',
#  92605: '06059',
#  92606: '06059',
#  92607: '06059',
#  92609: '06059',
#  92610: '06059',
#  92612: '06059',
#  92614: '06059',
#  92615: '06059',
#  92616: '06059',
#  92617: '06059',
#  92618: '06059',
#  92619: '06059',
#  92620: '06059',
#  92623: '06059',
#  92624: '06059',
#  92625: '06059',
#  92626: '06059',
#  92627: '06059',
#  92628: '06059',
#  92629: '06059',
#  92630: '06059',
#  92637: '06059',
#  92646: '06059',
#  92647: '06059',
#  92648: '06059',
#  92649: '06059',
#  92650: '06059',
#  92651: '06059',
#  92652: '06059',
#  92653: '06059',
#  92654: '06059',
#  92655: '06059',
#  92656: '06059',
#  92657: '06059',
#  92658: '06059',
#  92659: '06059',
#  92660: '06059',
#  92661: '06059',
#  92662: '06059',
#  92663: '06059',
#  92672: '06059',
#  92673: '06059',
#  92674: '06059',
#  92675: '06059',
#  92676: '06059',
#  92677: '06059',
#  92678: '06059',
#  92679: '06059',
#  92683: '06059',
#  92684: '06059',
#  92685: '06059',
#  92688: '06059',
#  92690: '06059',
#  92691: '06059',
#  92692: '06059',
#  92693: '06059',
#  92694: '06059',
#  92697: '06059',
#  92698: '06059',
#  92701: '06059',
#  92702: '06059',
#  92703: '06059',
#  92704: '06059',
#  92705: '06059',
#  92706: '06059',
#  92707: '06059',
#  92708: '06059',
#  92711: '06059',
#  92712: '06059',
#  92728: '06059',
#  92735: '06059',
#  92780: '06059',
#  92781: '06059',
#  92782: '06059',
#  92799: '06059',
#  92801: '06059',
#  92802: '06059',
#  92803: '06059',
#  92804: '06059',
#  92805: '06059',
#  92806: '06059',
#  92807: '06059',
#  92808: '06059',
#  92809: '06059',
#  ...}

# %%
import csv
output_file_path = 'zip_fips_mapping.csv'
with open(output_file_path, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['ZIP', 'FIPS'])
    for zip, fips in zip_fips_mapping.items():
        writer.writerow([zip, fips])

# %% [markdown]
# # Visualize the 2021 throughput data across California

# %% [markdown]
# ## First half

# %%
df = pd.read_csv('../data/measurement_test_2021-2023/2021_1.csv')
df.head(3)
# Out:
#      zip  throughput
# 0  95134   26.151214
# 1  94539   27.242447
# 2  95112   39.113374

# %%
mapping_df = pd.read_csv('../../tools&keys/zip_fips_mapping.csv', dtype={'FIPS': str})
mapping_df.head(3)
# Out:
#      ZIP   FIPS
# 0  90001  06037
# 1  90002  06037
# 2  90003  06037

# %%
zip_to_fips_series = mapping_df.set_index('ZIP')['FIPS']

# %%
df['fips'] = df['zip'].map(zip_to_fips_series)
df = df.drop('zip', axis=1)

# %%
df_throughput_by_fips = df.groupby('fips')['throughput'].mean().reset_index()

# %%
df_throughput_by_fips.head(3)
# Out:
#     fips  throughput
# 0  06001   56.191779
# 1  06005   70.934416
# 2  06007   75.370361

# %%
fig = px.choropleth_mapbox(df_throughput_by_fips, geojson=counties, locations='fips', color='throughput',
                           color_continuous_scale="Inferno",
                           range_color=(20, 80),
                           mapbox_style="basic",
                           zoom=4, center = {"lat": 38, "lon": -121},
                           opacity=0.5,
                           labels={'trp':'average throughput'}
                          )
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# fig.write_html('../graphs/2021_Jan_network.html')

# %% [markdown]
# # Set up a slider to see it on a timeline

# %%
df_2021_1 = df_throughput_by_fips.copy()
df_2021_1['period'] = '2021_1'
df_2021_1.head(3)
# Out:
#     fips  throughput  period
# 0  06001   56.191779  2021_1
# 1  06005   70.934416  2021_1
# 2  06007   75.370361  2021_1

# %%
df_combined = pd.DataFrame()
for period in ['2021_1', '2021_2', '2022_1', '2022_2', '2023_1', '2023_2']:
    df_sub = pd.read_csv(f'../data/measurement_test_2021-2023/{period}.csv')
    df_sub['fips'] = df_sub['zip'].map(zip_to_fips_series)
    df_sub = df_sub.drop('zip', axis=1)
    df_sub = df_sub.groupby('fips')['throughput'].mean().reset_index()
    df_sub['period'] = period
    df_combined = pd.concat([df_combined, df_sub])

# %%
df_combined
# Out:
#      fips  throughput  period
# 0   06001   56.191779  2021_1
# 1   06005   70.934416  2021_1
# 2   06007   75.370361  2021_1
# 3   06009   59.421754  2021_1
# 4   06011   53.427707  2021_1
# ..    ...         ...     ...
# 51  06107   74.832271  2023_2
# 52  06109   55.466826  2023_2
# 53  06111   77.614473  2023_2
# 54  06113   74.777702  2023_2
# 55  06115   71.297050  2023_2
#
# [341 rows x 3 columns]

# %%
fig = px.choropleth_mapbox(df_combined, 
                           geojson=counties, 
                           locations='fips', 
                           color='throughput',
                           color_continuous_scale="Inferno",
                           range_color=(20, 80),
                           mapbox_style="carto-positron",
                           zoom=4, 
                           center={"lat": 38, "lon": -121},
                           opacity=0.5,
                           labels={'throughput':'Average Throughput'},
                           animation_frame='period'  # This is where the half-year period column is used
                          )

fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
# fig.layout.pop("updatemenus")
fig.show()

# %%
fig.write_html('../graphs/2021-2023 slider.html')
